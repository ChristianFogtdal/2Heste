# %% [markdown]
# # Project Notebook
#
# ## Social Data Science - exam notebook
#
#
# #### Authors:
# #### Anton Maach-Møller
# #### Christian Nøjgaard Fogdal

# %% [markdown]
# ## 1. Installations

# %%
# pip install geopy
# pip install textblob
# pip install vaderSentiment
# pip install emoji
# nltk.download('stopwords')
# nltk.download('vader_lexicon')
# pip install statsmodels

# %% [markdown]
# ## 2. Import of used packages

# %%
# basic
import numpy as np
import pandas as pd

#packages to handle API connection
from tqdm import tqdm #progress bar, use code tqdm.pandas()
from time import sleep #module to control speed of extraction

# Twitter
import tweepy as tw # main twitter API package
from tqdm import tqdm #progress bar, use code tqdm.pandas()
from time import sleep #module to control speed of extraction

# Nominatim - API to access geo data
from geopy.geocoders import Nominatim #Geodata for datacleaning states
from geopy.exc import GeocoderTimedOut #Geodata for datacleaning states
from geopy.extra.rate_limiter import RateLimiter #rate limiter to geopy requests

# packages to handle string elements
import re #regex
from textblob import TextBlob #To analyse sentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer #Sentiment analyser
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import emoji #to "demojize" - translate emojis to text
import nltk #Natural Language Toolkit
import nltk.corpus 
from nltk.corpus import stopwords # list of stopwords to remove
from nltk.stem.porter import PorterStemmer #Stemming and lemmitization
from nltk.stem import WordNetLemmatizer #Stemming and lemmitization

# Machinelearning
from sklearn.model_selection import train_test_split #randomly split dataframe into test and train data
from sklearn.feature_extraction.text import TfidfVectorizer #
from sklearn.linear_model import LogisticRegression
import random #randomizer

# import webbrowser

# plots
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Extraction of data from Twitter

# %%
OBS
TRY TO USE wait_on_rate_limit 
AND
wait_on_rate_limit_notify

# %%
# Unique bearer token - is removed when published, since it is private
MY_BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAANcAaQEAAAAA84hzZvsLo8rITqxhQJoQHVAd5wI%3DfD5dXkdwihlc4K08dNi3y84D4lVhjiOIREITen9vVe2UVYxFh7"

# authentication using .client
client = tw.Client(bearer_token=MY_BEARER_TOKEN, wait_on_rate_limit=True)

# query to search for tweets
query = "#vaccine lang:en -is:retweet place_country:US has:geo"

# start and end time for fetching tweets
start_time = "2020-11-10T00:00:00Z"
end_time = "2021-01-04T00:00:00Z"

# get tweets from the API
tweets = client.search_all_tweets(   query=query,
                                     start_time=start_time,
                                     end_time=end_time,
                                     tweet_fields = [
                                                     "created_at", 
                                                     "text", 
                                                     "source", 
                                                     #"public_metrics"
                                                    ],
                                  
                                     user_fields = [
                                                    "name", 
                                                    "username", 
                                                    "location", 
                                                    "verified", 
                                                    "description"
                                                   ],
                                  
                                     place_fields=[
                                                   'place_type', 
                                                   'country', 
                                                   'country_code'
                                                  ],
                                  
                                     max_results = 500,
                                     #sort_order = ,
                                     expansions=['author_id', 'geo.place_id']
                                     )

# tweet specific info
print(len(tweets.data))
# user specific info
print(len(tweets.includes["users"]))
print(len(tweets.includes['places']))

# first tweet
first_tweet = tweets.data[0]
dict(first_tweet)

# user information for the first tweet
first_tweet_user = tweets.includes["users"][1]
dict(first_tweet_user)

first_tweet_place = tweets.includes['places'][1]
dict(first_tweet_place)


print("Total Tweets fetched:", len(tweets))
# Out:
# 491
# 332
# 241
# Total Tweets fetched: 4

# %% [markdown]
# ## 4. Creating dataframe from extracted data

# %%
# create a list of records
tweet_info_ls = []
# iterate over each tweet and corresponding user details
for tweet, user, place in zip(tweets.data, tweets.includes['users'], tweets.includes['places']):
    tweet_info = {
        'created_at': tweet.created_at,
        'text': tweet.text,
        'source': tweet.source,
        #'public_metrics': tweet.public_metrics,
        #'organic_metrics': tweet.organic_metrics,
        'name': user.name,
        'username': user.username,
        'user_location': user.location,
        'tweet_location': place.full_name,
        'country_code': place.country_code,
        #'country': user.country,
        'verified': user.verified,
        'description': user.description
    }
    tweet_info_ls.append(tweet_info)
# create dataframe from the extracted records
tweets_df = pd.DataFrame(tweet_info_ls)
# display the dataframe
tweets_df['text'][0]
# Out:
# "@VeryBadLlama It's not all Americans, just one that looks like 👇🏾👇🏾👇🏾. But there are 81,283,485 million Americans that voted to fix it by putting a #vaccine 💉 in that #TrumpVirus 🦠 that will be removed on January 20th. https://t.co/yiHWxKwlaE"

# %% [markdown]
# ## 5. Cleaning location variable and extracting geo data

# %% [markdown]
# ### Clean location data before extracting from Nomatim

# %%
def cleaner(document_location):
    """
    Cleaning location variable for:
    mentions (@user), 
    removes "#", 
    removes everything after "/" since some users has multiple locations split by "/", - we take the first location.
    try/except is used since the used method cannot be applied on empty values.
    """
    try:
        document_location = re.sub(r'@[^\s]+','',document_location) #removes @user
        document_location = re.sub(r'#[^\s]+','',document_location) #removes #hashtag
        document_location = re.sub(r'\/.*$','',document_location) #removes everything after / since some has multiple "homes", - we take the first
        #document_location = re.sub(r'[\d-]','',document_location) #removes digits
        #document_location = re.sub(r'[^\w\s]','', document_location) #Remove non-alphanumeric characters
        return document_location
    except:
        ("Some variable is None")

tweets_df['user_location'] = tweets_df['user_location'].apply(cleaner)
tweets_df
# Out:
#                    created_at  \
# 0   2021-01-03 22:42:29+00:00
# 1   2021-01-03 21:42:39+00:00
# 2   2021-01-03 21:31:47+00:00
# 3   2021-01-03 21:00:31+00:00
# 4   2021-01-03 20:25:43+00:00
# ..                        ...
# 236 2020-12-30 01:41:53+00:00
# 237 2020-12-30 00:53:55+00:00
# 238 2020-12-29 23:30:48+00:00
# 239 2020-12-29 23:00:55+00:00
# 240 2020-12-29 21:37:34+00:00
#
#                                                   text               source  \
# 0    @VeryBadLlama It's not all Americans, just one...  Twitter for Android
# 1    Rolling #2021 with a #covid #vaccine from #pfi...            Instagram
# 2    Our PD, Dr. OC received his 2nd dose of #pfize...   Twitter for iPhone
# 3    Here’s the info save time by completing the co...   Twitter for iPhone
# 4    Can we let Amazon handle the vaccinations ? Th...   Twitter for iPhone
# ..                                                 ...                  ...
# 236  I’m not against this take at all. Sooner or la...   Twitter for iPhone
# 237  A genuine #COVIDIOT #GymJordan would like you ...   Twitter for iPhone
# 238  At least some first responders where I work go...  Twitter for Android
# 239  “Blacks are 60% less likely than other racial ...   Twitter for iPhone
# 240  #NewHeroz 🦸🏾‍♂️ #15 \nhttps://t.co/pG0NyutH7b ...  Twitter for Android
#
#                        name         username                   user_location  \
# 0    Señor Pinky (we/us) 🇵🇷        MikeRosTX  BKLYN➡️Puerto Rico➡️Dallas, TX
# 1          DukeDuck, PharmD        DukeDuck1               San Francisco, CA
# 2         KP NapaSolano FMR   KPNapaSolanoFM          Napa-Solano California
# 3             SantiniReport    SantiniReport                            None
# 4                       J J      golfprojj10                   New York, USA
# ..                      ...              ...                             ...
# 236    Lisa Wallenda Picard          LWPinDC                        LoCo, Va
# 237         Daniel Margolis   DoctorMargolis                    New York, NY
# 238           Dru Lowenthal    xfileslover99                     Burbank, CA
# 239         RunStop/Restore  RunStopRestoreX                  Middletown, NY
# 240    Stephanie Smith, RRT       stephsmith                    Alabama, USA
#
#          tweet_location country_code  verified  \
# 0    Farmers Branch, TX           US     False
# 1     San Francisco, CA           US     False
# 2           Vallejo, CA           US     False
# 3        Cape Coral, FL           US     False
# 4            Roslyn, NY           US     False
# ..                  ...          ...       ...
# 236          Easton, MA           US     False
# 237      Five Forks, SC           US     False
# 238            Yuma, AZ           US     False
# 239   Oklahoma City, OK           US     False
# 240     Stony Brook, NY           US     False
#
#                                            description
# 0    #DevRel Community Manager🥑https://t.co/aH8DsAO...
# 1    Pharmacist inspired by kindness, cultures, & a...
# 2    Committed to social justice and to providing i...
# 3          Interested in all things South West Florida
# 4
# ..                                                 ...
# 236  Passionate Nats and Caps fan, Catholic, AT sec...
# 237                           Director of Prostate MRI
# 238  60’s liberal and full time resister!#BlueWave2022
# 239  18+ Only! #Neurodivergent #Intersex #SteamID:R...
# 240                            A Rick Steves fan girl.
#
# [241 rows x 10 columns]

# %% [markdown]
# ### Collecting data from Nomatim using GeoPy

# %%
geolocator = Nominatim(user_agent="Christian Fogtdal, Student at Copenhagen University, rxw556@alumni.ku.dk")

def city_state_country(row):
    """
    Using Nomatim API to get consistant data of city/state/country from a given country string, 
    - problem was that Twitter users either has "city, state" or "state, country", or something even less usable since location is a free text field.
    
    The code iterates over each row, and extracts city/state/country if applicable.
    Sleep time is set to 1 second. - This is requested by the provider.
    If not applicable the code returns the input.
    """
    coord = f"{row['tweet_location']}"
    sleep(1) #Nomatim is free to use, but requires users to only request 60x/min
    tqdm.pandas() # show progress
    location = geolocator.geocode(coord,exactly_one=True, addressdetails=True)
    if not location:
        # if you see many in a row, it's probably Nominatim blocking you.
        # if it's just every once in a while, there were just some bad results. 
        print('Failed with location: ', coord)
        row['city'], row['state'], row['country'] = None, None, None
        return row
    address = location.raw['address']
    city = address.get('city', '')
    state = address.get('state', '')
    country = address.get('country', '')
    row['city'] = city
    row['state'] = state
    row['country'] = country
    return row

tweets_df = tweets_df.apply(city_state_country, axis=1)
tweets_df
# Out:
# Failed with location:  Asthma And Allergy Wellness Center
# Failed with location:  West Carrollton City, OH
#                    created_at  \
# 0   2021-01-09 23:53:47+00:00
# 1   2021-01-09 23:48:26+00:00
# 2   2021-01-09 23:47:50+00:00
# 3   2021-01-09 22:24:03+00:00
# 4   2021-01-09 22:02:11+00:00
# ..                        ...
# 253 2021-01-04 15:28:01+00:00
# 254 2021-01-04 15:19:29+00:00
# 255 2021-01-04 14:35:54+00:00
# 256 2021-01-04 13:41:11+00:00
# 257 2021-01-04 13:37:46+00:00
#
#                                                   text               source  \
# 0    94 minutes in I join @DanBarreiroKFAN @jgkfan ...   Twitter for iPhone
# 1    So when are we going to stop wearing these mas...  Twitter for Android
# 2    Second dose done! 🙌🏼 #imdonewithyou #covid19 #...            Instagram
# 3    Real question - how are you notified when you’...   Twitter for iPhone
# 4    COVID Vaccination: Episode 1. Glad to be a par...   Twitter for iPhone
# ..                                                 ...                  ...
# 253  Waiting to get my #VACCINE for #COVID19  nervo...  Twitter for Android
# 254  😬... But did get my second vaccine dose today!...   Twitter for iPhone
# 255  I finally got my first shot covid 19 vaccine, ...   Twitter for iPhone
# 256  16 million short on the promised vaccination g...   Twitter for iPhone
# 257  GOOD MORNING!\nToday is the day I get my #Covi...   Twitter for iPhone
#
#                                                name         username  \
# 0                              Bill Morice, MD, PhD      moricemdphd
# 1                                   Stuntman Mike 🤬       Thadvdking
# 2                                      ✨🌺 ʑıɛŋŋɛ 🌺✨     kriziennelyn
# 3                                         Christina    notNksanymore
# 4                               Prabhu Mathiyalagan      Prabhu_gene
# ..                                              ...              ...
# 253                                    Nancy Janitz          NJanitz
# 254                                               j  foulmouthmuggle
# 255                                     EmmEmmPotts      APenToPaper
# 256                                American Veteran   JerseyJohn1580
# 257  Sanjay Kalra, Digital Transformation Sherpa 🇮🇳      sanjaykalra
#
#                      user_location      tweet_location country_code  verified  \
# 0                    Rochester, MN      Minnesota, USA           US     False
# 1                    Baltimore, MD       Baltimore, MD           US     False
# 2    somewhere you could call home        San Jose, CA           US     False
# 3                San Francisco, CA       San Ramon, CA           US     False
# 4            Lausanne, Switzerland       Manhattan, NY           US     False
# ..                             ...                 ...          ...       ...
# 253            Jacksonville, N.C.            Largo, FL           US     False
# 254                     Austin, TX     Friendswood, TX           US     False
# 255                    Houston, TX       Chantilly, VA           US     False
# 256                            USA        Chandler, AZ           US     False
# 257              San Francisco, CA  Salt Lake City, UT           US     False
#
#                                            description              city  \
# 0    President of @MayoClinicLabs and Chair of Lab ...
# 1    I keep my Head up my ass to see shit clearly a...         Baltimore
# 2        I'm an ever-changing person, so deal with it.          San Jose
# 3    Kansas born 🌻🌻 • California living 🌴🌊 • Cat mo...
# 4    Husband & Dad. RNA, EV, gene therapy in🫀🫁 🩸Pas...  City of New York
# ..                                                 ...               ...
# 253  I'm a Mother, Grand MA! & A *Domestitic Vioile...             Largo
# 254                    goofabout, curator and polymath
# 255  I argue a lot. Also a lawyer, writer, coffee c...
# 256  Navy Veteran,  father of three,  a beautiful w...          Chandler
# 257  Helping my customers navigate Digital Transfor...    Salt Lake City
#
#           state        country
# 0     Minnesota  United States
# 1      Maryland  United States
# 2    California  United States
# 3    California  United States
# 4      New York  United States
# ..          ...            ...
# 253     Florida  United States
# 254       Texas  United States
# 255    Virginia  United States
# 256     Arizona  United States
# 257        Utah  United States
#
# [258 rows x 13 columns]

# %% [markdown]
# ### Final clean of location data

# %%
# Removes rows, where country != 'United States'.
# This is often due to free text, where the user for example has written 'my bed' or 'the city'
# I.e. 'the city' returns "City of London", which is why it is removed.
tweets_df = tweets_df.drop(tweets_df[tweets_df.country != 'United States'].index)

#Empty values to NaN
tweets_df['city'].replace('', np.nan, inplace=True)
tweets_df['state'].replace('', np.nan, inplace=True)

# Also removes rows without state info
tweets_df[~tweets_df['state'].isnull()]
tweets_df.dropna(subset=['state'], inplace=True)
len(tweets_df)
# Out:
# 255

# %% [markdown]
# ## 6. Cleaning of the tweet text

# %%
## Making a copy, to not be forced to load from the start every time
tweets_df2 = tweets_df.copy()

# %%
tweets_df['text'][0]
# Out:
# 'There’s no reason — NONE. WHATSOEVER. — to waste any dose of the COVID vaccine. \n\nWe’ve ground our way of life to a halt for almost a year. \n\nWe were told a vaccine was the way out of this. \n\nAnd now that we have it...we won’t want as many people as possible to get it?'

# %% [markdown]
# ### Cleaner for the text variable

# %%
def cleaner_text(document_tweet):
    """
    Cleaning tweet text for:
    replacing \n newlines with white space ' ',
    lower case everything,
    removes mentions (@user), 
    removes "#" before hashtags and keeps the text, 
    removes digits, 
    removes http-links,
    """
    document_tweet = re.sub(r'\r\n|\r|\n', ' ', document_tweet) #replaces newline with with space
    document_tweet = document_tweet.lower() #To lower case
    document_tweet = re.sub(r'@[^\s]+','',document_tweet) #removes @user
    document_tweet = re.sub(r'[#]','',document_tweet) #Removes only #-sign
    document_tweet = re.sub(r'[\d-]','',document_tweet) #removes digits
    document_tweet = re.sub(r'http[^\s]+','',document_tweet) #removes links starting with https
    document_tweet = re.sub(r'[^\w\s]','', document_tweet) #Remove non-alphanumeric characters
    #document_tweet = re.sub(r'#[^\s]+','',document_tweet) #removes "#" and #hashtagstring
    return document_tweet

tweets_df2['text'] = tweets_df2['text'].apply(cleaner_text)

# %% [markdown]
# ### Translate emojis to text

# %%
def demojize_text(text_tweet):
    """
    translates emojis to text.
    """
    return emoji.demojize(text_tweet, delimiters=("", " "))

tweets_df2['text'] = tweets_df2['text'].apply(demojize_text)

# %% [markdown]
# ### Removing stop words

# %%
def remove_stopwords(tweet_text):
    """
    removes stop words defined by package nltk.corpus
    """
    stop = stopwords.words('english')
    tweet_text = " ".join([word for word in tweet_text.split() if word not in (stop)])
    return tweet_text

tweets_df2['text'] = tweets_df2['text'].apply(remove_stopwords)

# %% [markdown]
# ### Apply the sentiment analysis using Vader

# %%
# Vader sentiment analysis
def sentiment_analyser(tweet_text):
    """
    Using Vader as sentiment analyser.
    Vader outputs neg, neu, pos and compound, - we only keep compound.
    This is done for each tweet.
    """
    analyser= SentimentIntensityAnalyzer()
    sentiment_score = analyser.polarity_scores(tweet_text)["compound"]
    return sentiment_score

# sentiment score from -1 to 1
tweets_df2['sentiment_score'] = tweets_df2['text'].apply(sentiment_analyser)

# boolean value is 0 if sentiment is negative, else 1
tweets_df2['tweet_sentiment'] = [0 if i < 0 else 1 for i in tweets_df2.sentiment_score]
len(tweets_df2)
# Out:
# 255

# %%
# Creating dataset
data = tweets_df2['sentiment_score']

fig = plt.figure(figsize =(7, 7))

# Creating plot
plt.boxplot(data, vert=True)

# show plot
plt.show()

# %%
Axes.violinplot(dataset, positions=None, vert=True, widths=0.5, showmeans=False, showextrema=True, showmedians=False, quantiles=None, points=100, bw_method=None, *, data=None)

# %%
import statsmodels.api as sm
import pandas as pd

# defining the variables
x = df['sentiment_score'].tolist()
y = df['state'].tolist()
plt.scatter(x, y)

max_x = df['sentiment_score'].max()
min_x = df['sentiment_score'].min()

x = np.arange(min_x, max_x, 1)

# adding the constant term
#x = sm.add_constant(x)
 
# performing the regression
# and fitting the model
#result = sm.OLS(y, x).fit()

# printing the summary table
#print(result.summary())

# %%
tweets_df2_test = tweets_df2.loc[tweets_df2['state'] == 'Florida']

# %%
df_new = tweets_df2.groupby('state') \
       .agg(count=('state', 'size'), mean_sentiment=('sentiment_score', 'mean')) \
       .reset_index()

#df_new2 = df_new.loc[df_new['count'] > 4]

df_new3 = df_new.sort_values('state', ascending=True, inplace=False, kind='quicksort', na_position='last')
df_new3
# Out:
#                    state  count  mean_sentiment
# 0                Alabama      3       -0.001867
# 1                Arizona      5       -0.439240
# 2               Arkansas      1       -0.318200
# 3             California     27       -0.037307
# 4               Colorado      5        0.235180
# 5            Connecticut      2        0.210750
# 6               Delaware      1        0.318200
# 7   District of Columbia      2        0.030950
# 8                Florida     25        0.125764
# 9                Georgia      4        0.235925
# 10                Hawaii      3        0.457333
# 11                 Idaho      2       -0.448700
# 12              Illinois      6       -0.255700
# 13               Indiana      4        0.117950
# 14                  Iowa      3        0.562000
# 15                Kansas      1        0.827100
# 16              Kentucky      7        0.006014
# 17             Louisiana      3        0.474667
# 18                 Maine      4        0.289675
# 19              Maryland      7        0.262771
# 20         Massachusetts      3       -0.084867
# 21              Michigan      4       -0.008900
# 22             Minnesota      4       -0.211925
# 23           Mississippi      3       -0.364000
# 24              Missouri      3        0.170600
# 25              Nebraska      5        0.270860
# 26                Nevada      2       -0.028600
# 27         New Hampshire      4        0.363625
# 28            New Jersey      8        0.041000
# 29            New Mexico      1        0.000000
# 30              New York     16        0.234369
# 31        North Carolina      7        0.189800
# 32          North Dakota      1       -0.421500
# 33                  Ohio      7        0.043057
# 34              Oklahoma      1       -0.135100
# 35                Oregon      2        0.000000
# 36          Pennsylvania      5        0.162220
# 37          Rhode Island      1        0.296000
# 38        South Carolina      2        0.306200
# 39             Tennessee      7       -0.120129
# 40                 Texas     29       -0.026521
# 41                  Utah      1        0.000000
# 42              Virginia      9        0.026544
# 43            Washington      8       -0.011350
# 44         West Virginia      2       -0.180600
# 45             Wisconsin      5        0.001780

# %%
tweets_df2
# Out:
#                    created_at  \
# 0   2021-01-04 23:59:24+00:00
# 1   2021-01-04 23:59:06+00:00
# 2   2021-01-04 23:58:24+00:00
# 3   2021-01-04 23:57:27+00:00
# 4   2021-01-04 23:57:21+00:00
# ..                        ...
# 240 2021-01-04 21:24:21+00:00
# 241 2021-01-04 21:23:49+00:00
# 242 2021-01-04 21:23:46+00:00
# 244 2021-01-04 21:21:25+00:00
# 245 2021-01-04 21:20:41+00:00
#
#                                                   text               source  \
# 0    theres no reason  none whatsoever  to waste an...   Twitter for iPhone
# 1    union co will begin to offer phase a covid vac...   Twitter for iPhone
# 2        my family is ready and willing but were un...   Twitter for iPhone
# 3    if a new wave of infections as a result of a n...   Twitter for iPhone
# 4     yes the republicans save the america they clo...  Twitter for Android
# ..                                                 ...                  ...
# 240  if you have ever accidentally drank from your ...   Twitter for iPhone
# 241   i know our president is making many phone cal...   Twitter for iPhone
# 242   im a  yearold cancer patient my oncologist to...   Twitter for iPhone
# 244  brandenburg told investigators that he believe...   Twitter for iPhone
# 245           update on jan vaccine allocationsgtgtgt    Twitter for iPhone
#
#                                   name         username  \
# 0                           Amy Curtis   RantyAmyCurtis
# 1    Committeeman Christopher Capodice    ChrisCapodice
# 2                       Shannon Marino      smarino1002
# 3                          Adam Merino       adammerino
# 4                    Sharon Perreault   SharonPerreaul1
# ..                                 ...              ...
# 240                              Steve       iim_riskyy
# 241                            jet jet    JetDaAirplane
# 242                    Brandon Shaw 🇺🇸        Bshaw_140
# 244                        Jo Langston          TTUprof
# 245               Tao Dao Man 😷🌵☮☯️🍀🇨🇳        TaoDaoMan
#
#                 user_location      tweet_location country_code  verified  \
# 0               Milwaukee, WI       Milwaukee, WI           US     False
# 1             Springfield, NJ     Springfield, NJ           US     False
# 2                 Houston, TX         Tomball, TX           US     False
# 3              New York City    San Francisco, CA           US     False
# 4                        None           Leola, PA           US     False
# ..                        ...                 ...          ...       ...
# 240              Rhode Island  Corpus Christi, TX           US     False
# 241           New Jersey, USA     New Jersey, USA           US     False
# 242  The Gunshine State 🏴‍☠️       Long Beach, CA           US     False
# 244                      None     Oswego Hospital           US     False
# 245                The Cosmos    Williamsburg, KY           US     False
#
#                                            description            city  \
# 0    RN, Mom, traditional Catholic, combative nerd....       Milwaukee
# 1    Former Mayor, currently serves as Township Com...             NaN
# 2    Higher Ed/Student Affairs. Have courage and be...             NaN
# 3    @forbes Top Next-Gen Wealth Advisor @SpecOlymp...   San Francisco
# 4    I am a happily married woman who has 4 childre...             NaN
# ..                                                 ...             ...
# 240                                                     Corpus Christi
# 241                    simon: BABY!! :0 me: yes, honey             NaN
# 242  'This world is mine, Chico, and everything in ...      Long Beach
# 244  Loving being in my 60s! Christian, mother, fri...  City of Oswego
# 245  BDS. Anti-Zionism. Anti-Fascist. Anti-War. Chr...             NaN
#
#             state        country  sentiment_score  tweet_sentiment
# 0       Wisconsin  United States          -0.0232                0
# 1      New Jersey  United States           0.7269                1
# 2           Texas  United States          -0.5483                0
# 3      California  United States           0.3818                1
# 4    Pennsylvania  United States           0.7783                1
# ..            ...            ...              ...              ...
# 240         Texas  United States           0.0015                1
# 241    New Jersey  United States           0.4215                1
# 242    California  United States          -0.2144                0
# 244      New York  United States          -0.8362                0
# 245      Kentucky  United States           0.0000                1
#
# [239 rows x 15 columns]

# %% [markdown]
# ## Machine learning

# %% [markdown]
# ### test train split

# %%
tweets_df3 = tweets_df2.copy()

# %%
# list of tweet sentiments
tweet_sentiments = [0 if i<0 else 1 for i in tweets_df3.sentiment_score]

# %%
# splitting dataset into test and train
df_train, df_test = train_test_split(tweets_df3, test_size=.5, random_state=1337)

# %%
# Sort the data randomly to mix positive and negative reviews
np.random.seed(0)
df_train = tweets_df2.reindex(np.random.permutation(df_train.index))
df_test = tweets_df2.reindex(np.random.permutation(df_test.index))

# Take out X and Y variable
x_train = df_train['text'].values
x_test = df_test['text'].values
y_train = df_train['tweet_sentiment'].values
y_test = df_test['tweet_sentiment'].values

# Make our bag of words
tfidf = TfidfVectorizer()
x_train_bag = tfidf.fit_transform(x_train)

# Fit the model
lr_text = LogisticRegression(random_state=0) #Text classifier
lr_text.fit(x_train_bag,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
tweets_bag = tfidf.transform(tweets_df3['text'].values)

preds = lr_text.predict(tweets_bag)
print("Testing accuracy =",np.mean([(preds==tweets_df2['tweet_sentiment'])]))
# Out:
# Testing accuracy = 0.6820083682008368

# %% [markdown]
# ### ML v2

# %%
tweets_df3.head()
# Out:
#                  created_at  \
# 0 2021-01-04 23:59:24+00:00
# 1 2021-01-04 23:59:06+00:00
# 2 2021-01-04 23:58:24+00:00
# 3 2021-01-04 23:57:27+00:00
# 4 2021-01-04 23:57:21+00:00
#
#                                                 text               source  \
# 0  theres no reason  none whatsoever  to waste an...   Twitter for iPhone
# 1  union co will begin to offer phase a covid vac...   Twitter for iPhone
# 2      my family is ready and willing but were un...   Twitter for iPhone
# 3  if a new wave of infections as a result of a n...   Twitter for iPhone
# 4   yes the republicans save the america they clo...  Twitter for Android
#
#                                 name         username    user_location  \
# 0                         Amy Curtis   RantyAmyCurtis    Milwaukee, WI
# 1  Committeeman Christopher Capodice    ChrisCapodice  Springfield, NJ
# 2                     Shannon Marino      smarino1002      Houston, TX
# 3                        Adam Merino       adammerino   New York City
# 4                  Sharon Perreault   SharonPerreaul1             None
#
#       tweet_location country_code  verified  \
# 0      Milwaukee, WI           US     False
# 1    Springfield, NJ           US     False
# 2        Tomball, TX           US     False
# 3  San Francisco, CA           US     False
# 4          Leola, PA           US     False
#
#                                          description           city  \
# 0  RN, Mom, traditional Catholic, combative nerd....      Milwaukee
# 1  Former Mayor, currently serves as Township Com...            NaN
# 2  Higher Ed/Student Affairs. Have courage and be...            NaN
# 3  @forbes Top Next-Gen Wealth Advisor @SpecOlymp...  San Francisco
# 4  I am a happily married woman who has 4 childre...            NaN
#
#           state        country  sentiment_score  tweet_sentiment
# 0     Wisconsin  United States          -0.0232                0
# 1    New Jersey  United States           0.7269                1
# 2         Texas  United States          -0.5483                0
# 3    California  United States           0.3818                1
# 4  Pennsylvania  United States           0.7783                1

# %%
# Make our bag of words
tfidf_tweet = TfidfVectorizer()
tweets_new_bag = tfidf_tweet.fit_transform(tweets_df3['text'].values)

# Fit the model
lr_tweets = LogisticRegression(random_state=0) #Text classifier
lr_tweets.fit(tweets_new_bag, tweet_sentiments)
# Out:
# LogisticRegression(random_state=0)

# %%
# Make our bag of words
tweets_features = ['_'.join(s.split()) for s in tfidf_tweet.get_feature_names_out()]
tweets_coefficients = lr_tweets.coef_
tweets_coefs_df = pd.DataFrame.from_records(tweets_coefficients, columns=tweets_features)

# Most important (positive and negative) features:
print()
print(tweets_coefs_df.T.sort_values(by=[0], ascending=False).head(50))
print()
print(tweets_coefs_df.T.sort_values(by=[0], ascending=True).head(50))
# Out:
#                      0
# got           0.875174
# need          0.572002
# vaccine       0.511141
# today         0.476357
# covid         0.472806
# make          0.453994
# return        0.417495
# update        0.404519
# one           0.368894
# next          0.366469
# first         0.361679
# rona          0.355477
# done          0.334313
# received      0.328062
# great         0.321149
# right         0.311540
# get           0.310537
# system        0.307344
# good          0.299067
# peoples       0.297170
# shot          0.291972
# signed        0.289751
# distributed   0.284186
# mom           0.283787
# metal         0.282932
# thanks        0.275665
# end           0.272070
# available     0.269083
# grateful      0.266864
# away          0.266731
# announced     0.262456
# johnson       0.260328
# appointments  0.254507
# definitely    0.254136
# man           0.250894
# biden         0.250274
# january       0.248600
# working       0.247228
# enough        0.244003
# vaccines      0.242781
# sitting       0.236780
# please        0.235088
# youve         0.234453
# well          0.232792
# soon          0.230759
# wow           0.226583
# opportunity   0.223367
# flu           0.223205
# south         0.222246
# positive      0.218456
#
#                       0
# us            -0.701449
# conspiracy    -0.675291
# medical       -0.590328
# ill           -0.584164
# anyone        -0.550803
# try           -0.535887
# line          -0.504130
# people        -0.485031
# states        -0.478494
# virus         -0.466980
# theorist      -0.461374
# worry         -0.447056
# dead          -0.440984
# lack          -0.429956
# unfortunately -0.422641
# worse         -0.415045
# website       -0.405302
# rollout       -0.400937
# pandemic      -0.399203
# fuck          -0.397418
# half          -0.380028
# gotta         -0.374235
# post          -0.365519
# keep          -0.354503
# vaccinated    -0.354151
# asthma        -0.354135
# still         -0.354079
# adoption      -0.353556
# nc            -0.349396
# bc            -0.347876
# brandenburg   -0.342380
# tried         -0.340069
# take          -0.338310
# wanna         -0.336063
# family        -0.330469
# supremacy     -0.322989
# shocking      -0.316784
# guessed       -0.316784
# nycs          -0.316310
# said          -0.313479
# considering   -0.313029
# drugs         -0.302270
# drunk         -0.301229
# chilling      -0.301229
# dna           -0.299352
# group         -0.294333
# game          -0.293707
# left          -0.291153
# im            -0.288435
# incompetent   -0.285564

# %% [markdown]
# ### Tokenization

# %%
text_tokens = nltk.tokenize.word_tokenize(text)
text_tokens
# Out:
# ['received',
#  'first',
#  'two',
#  'covid',
#  'vaccine',
#  'today',
#  'first',
#  'responder',
#  'thanks',
#  'personnel',
#  'great',
#  'job',
#  'us']

# %% [markdown]
# ### Stemming

# %%
porter = nltk.PorterStemmer()
review_stemmed = [porter.stem(i) for i in review_nostop]
review_stemmed
# Out:
# received first two covid vaccine today first responder. thanks personnel great job us! = received first two covid vaccine today first responder. thanks personnel great job us!

# %% [markdown]
# ## 7. Scraping of 2020 US presidential election results from Wiki

# %%
df_table = pd.read_html('https://en.wikipedia.org/wiki/2020_United_States_presidential_election')
table_election_state = df_table[19]
table_election_state

# rename state
# new variable state=Red/Blue
# Remove unnecessesary variables
# Out:
#    State ordistrict  Biden/HarrisDemocratic                          \
#    State ordistrict                   Votes                       %
# 0             Alab.                  849624                  36.57%
# 1            Alaska                  153778                  42.77%
# 2           Arizona                 1672143                  49.36%
# 3              Ark.                  423932                  34.78%
# 4            Calif.                11110250                  63.48%
# 5             Colo.                 1804352                  55.40%
# 6             Conn.                 1080831                  59.26%
# 7              Del.                  296268                  58.74%
# 8              D.C.                  317323                  92.15%
# 9           Florida                 5297045                  47.86%
# 10          Georgia                 2473633                  49.47%
# 11           Hawaii                  366130                  63.73%
# 12            Idaho                  287021                  33.07%
# 13         Illinois                 3471915                  57.54%
# 14          Indiana                 1242416                  40.96%
# 15             Iowa                  759061                  44.89%
# 16           Kansas                  570323                  41.56%
# 17              Ky.                  772474                  36.15%
# 18              La.                  856034                  39.85%
# 19          Maine †                  435072                  53.09%
# 20             ME-1                  266376                  60.11%
# 21             ME-2                  168696                  44.82%
# 22              Md.                 1985023                  65.36%
# 23            Mass.                 2382202                  65.60%
# 24            Mich.                 2804040                  50.62%
# 25            Minn.                 1717077                  52.40%
# 26            Miss.                  539398                  41.06%
# 27              Mo.                 1253014                  41.41%
# 28            Mont.                  244786                  40.55%
# 29           Neb. †                  374583                  39.17%
# 30             NE-1                  132261                  41.09%
# 31             NE-2                  176468                  51.95%
# 32             NE-3                   65854                  22.34%
# 33          Nev.[p]                  703486                  50.06%
# 34             N.H.                  424937                  52.71%
# 35          N.J.[q]                 2608335                  57.33%
# 36             N.M.                  501614                  54.29%
# 37          N.Y.[r]                 5230985                  60.86%
# 38             N.C.                 2684292                  48.59%
# 39             N.D.                  114902                  31.76%
# 40             Ohio                 2679165                  45.24%
# 41            Okla.                  503890                  32.29%
# 42           Oregon                 1340383                  56.45%
# 43              Pa.                 3458229                  50.01%
# 44             R.I.                  307486                  59.39%
# 45             S.C.                 1091541                  43.43%
# 46             S.D.                  150471                  35.61%
# 47            Tenn.                 1143711                  37.45%
# 48         Texas[t]                 5259126                  46.48%
# 49             Utah                  560282                  37.65%
# 50              Vt.                  242820                  66.09%
# 51              Va.                 2413568                  54.11%
# 52            Wash.                 2369612                  57.97%
# 53            W.Va.                  235984                  29.69%
# 54             Wis.                 1630866                  49.45%
# 55             Wyo.                   73491                  26.55%
# 56            Total                81268924                  51.31%
# 57              NaN  Biden/HarrisDemocratic  Biden/HarrisDemocratic
#
#                             Trump/PenceRepublican                         \
#                         EV                  Votes                      %
# 0                        –                1441170                 62.03%
# 1                        –                 189951                 52.83%
# 2                       11                1661686                 49.06%
# 3                        –                 760647                 62.40%
# 4                       55                6006429                 34.32%
# 5                        9                1364607                 41.90%
# 6                        7                 714717                 39.19%
# 7                        3                 200603                 39.77%
# 8                        3                  18586                  5.40%
# 9                        –                5668731                 51.22%
# 10                      16                2461854                 49.24%
# 11                       4                 196864                 34.27%
# 12                       –                 554119                 63.84%
# 13                      20                2446891                 40.55%
# 14                       –                1729519                 57.02%
# 15                       –                 897672                 53.09%
# 16                       –                 771406                 56.21%
# 17                       –                1326646                 62.09%
# 18                       –                1255776                 58.46%
# 19                       2                 360737                 44.02%
# 20                       1                 164045                 37.02%
# 21                       –                 196692                 52.26%
# 22                      10                 976414                 32.15%
# 23                      11                1167202                 32.14%
# 24                      16                2649852                 47.84%
# 25                      10                1484065                 45.28%
# 26                       –                 756764                 57.60%
# 27                       –                1718736                 56.80%
# 28                       –                 343602                 56.92%
# 29                       –                 556846                 58.22%
# 30                       –                 180290                 56.01%
# 31                       1                 154377                 45.45%
# 32                       –                 222179                 75.36%
# 33                       6                 669890                 47.67%
# 34                       4                 365660                 45.36%
# 35                      14                1883274                 41.40%
# 36                       5                 401894                 43.50%
# 37                      29                3244798                 37.75%
# 38                       –                2758775                 49.93%
# 39                       –                 235595                 65.11%
# 40                       –                3154834                 53.27%
# 41                       –                1020280                 65.37%
# 42                       7                 958448                 40.37%
# 43                      20                3377674                 48.84%
# 44                       4                 199922                 38.61%
# 45                       –                1385103                 55.11%
# 46                       –                 261043                 61.77%
# 47                       –                1852475                 60.66%
# 48                       –                5890347                 52.06%
# 49                       –                 865140                 58.13%
# 50                       3                 112704                 30.67%
# 51                      13                1962430                 44.00%
# 52                      12                1584651                 38.77%
# 53                       –                 545382                 68.62%
# 54                      10                1610184                 48.82%
# 55                       –                 193559                 69.94%
# 56                     306               74216154                 46.86%
# 57  Biden/HarrisDemocratic  Trump/PenceRepublican  Trump/PenceRepublican
#
#                            Jorgensen/CohenLibertarian  \
#                        EV                       Votes
# 0                       9                       25176
# 1                       3                        8897
# 2                       –                       51465
# 3                       6                       13133
# 4                       –                      187895
# 5                       –                       52460
# 6                       –                       20230
# 7                       –                        5000
# 8                       –                        2036
# 9                      29                       70324
# 10                      –                       62229
# 11                      –                        5539
# 12                      4                       16404
# 13                      –                       66544
# 14                     11                       59232
# 15                      6                       19637
# 16                      6                       30574
# 17                      8                       26234
# 18                      8                       21645
# 19                      –                       14152
# 20                      –                        7343
# 21                      1                        6809
# 22                      –                       33488
# 23                      –                       47013
# 24                      –                       60381
# 25                      –                       34976
# 26                      6                        8026
# 27                     10                       41205
# 28                      3                       15252
# 29                      2                       20283
# 30                      1                        7495
# 31                      –                        6909
# 32                      1                        5879
# 33                      –                       14783
# 34                      –                       13236
# 35                      –                       31677
# 36                      –                       12585
# 37                      –                       60234
# 38                     15                       48678
# 39                      3                        9393
# 40                     18                       67569
# 41                      7                       24731
# 42                      –                       41582
# 43                      –                       79380
# 44                      –                        5053
# 45                      9                       27916
# 46                      3                       11095
# 47                     11                       29877
# 48                     38                      126243
# 49                      6                       38447
# 50                      –                        3608
# 51                      –                       64761
# 52                      –                       80500
# 53                      5                       10687
# 54                      –                       38491
# 55                      3                        5768
# 56                    232                     1865724
# 57  Trump/PenceRepublican  Jorgensen/CohenLibertarian
#
#                                                             \
#                              %                          EV
# 0                        1.08%                           –
# 1                        2.47%                           –
# 2                        1.52%                           –
# 3                        1.08%                           –
# 4                        1.07%                           –
# 5                        1.61%                           –
# 6                        1.11%                           –
# 7                        0.99%                           –
# 8                        0.59%                           –
# 9                        0.64%                           –
# 10                       1.24%                           –
# 11                       0.96%                           –
# 12                       1.89%                           –
# 13                       1.10%                           –
# 14                       1.95%                           –
# 15                       1.16%                           –
# 16                       2.23%                           –
# 17                       1.23%                           –
# 18                       1.01%                           –
# 19                       1.73%                           –
# 20                       1.66%                           –
# 21                       1.81%                           –
# 22                       1.10%                           –
# 23                       1.29%                           –
# 24                       1.09%                           –
# 25                       1.07%                           –
# 26                       0.61%                           –
# 27                       1.36%                           –
# 28                       2.53%                           –
# 29                       2.12%                           –
# 30                       2.33%                           –
# 31                       2.03%                           –
# 32                       1.99%                           –
# 33                       1.05%                           –
# 34                       1.64%                           –
# 35                       0.70%                           –
# 36                       1.36%                           –
# 37                       0.70%                           –
# 38                       0.88%                           –
# 39                       2.60%                           –
# 40                       1.14%                           –
# 41                       1.58%                           –
# 42                       1.75%                           –
# 43                       1.15%                           –
# 44                       0.98%                           –
# 45                       1.11%                           –
# 46                       2.63%                           –
# 47                       0.98%                           –
# 48                       1.12%                           –
# 49                       2.58%                           –
# 50                       0.98%                           –
# 51                       1.45%                           –
# 52                       1.97%                           –
# 53                       1.34%                           –
# 54                       1.17%                           –
# 55                       2.08%                           –
# 56                       1.18%                           –
# 57  Jorgensen/CohenLibertarian  Jorgensen/CohenLibertarian
#
#     Hawkins/WalkerGreen                                              Others  \
#                   Votes                    %                   EV     Votes
# 0                   [m]                  [m]                    –      7312
# 1                   [n]                  [n]                    –      6904
# 2                  1557                0.05%                    –       475
# 3                  2980                0.24%                    –     18377
# 4                 81029                0.46%                    –    115278
# 5                  8986                0.28%                    –     26575
# 6                  7538                0.41%                    –       541
# 7                  2139                0.42%                    –       336
# 8                  1726                0.50%                    –      4685
# 9                 14721                0.13%                    –     16635
# 10                 1013                0.02%                    –      1231
# 11                 3822                0.67%                    –      2114
# 12                  407                0.05%                    –     10063
# 13                30494                0.51%                    –     17900
# 14                  989                0.03%                    –       965
# 15                 3075                0.18%                    –     11426
# 16               669[o]             0.05%[o]                    –  1,014[o]
# 17                  716                0.03%                    –     10698
# 18                    –                    –                    –     14607
# 19                 8230                1.00%                    –      1270
# 20                 4654                1.05%                    –       694
# 21                 3576                0.95%                    –       576
# 22                15799                0.52%                    –     26306
# 23                18658                0.51%                    –     16327
# 24                13718                0.25%                    –     11311
# 25                10033                0.31%                    –     31020
# 26                 1498                0.11%                    –      8073
# 27                 8283                0.27%                    –      4724
# 28                    –                    –                    –        34
# 29                  [m]                  [m]                    –      4671
# 30                  [m]                  [m]                    –      1840
# 31                  [m]                  [m]                    –      1912
# 32                  [m]                  [m]                    –       919
# 33                    –                    –                    –     17217
# 34                  217                0.03%                    –      2155
# 35                14202                0.31%                    –     11865
# 36                 4426                0.48%                    –      3446
# 37                32753                0.38%                    –     26056
# 38                12195                0.22%                    –     20864
# 39                  [m]                  [m]                    –      1929
# 40                18812                0.32%                    –      1822
# 41                    –                    –                    –     11798
# 42                11831                0.50%                    –     22077
# 43                  [s]                  [s]                    –       [s]
# 44                  [m]                  [m]                    –      5296
# 45                 6907                0.27%                    –      1862
# 46                    –                    –                    –         –
# 47                 4545                0.15%                    –     23243
# 48                33396                0.30%                    –      5944
# 49                 5053                0.34%                    –     19367
# 50                 1310                0.36%                    –      6986
# 51                  [m]                  [m]                    –     19765
# 52                18289                0.45%                    –     34579
# 53                 2599                0.33%                    –        79
# 54                 1089                0.03%                    –     17411
# 55                  [m]                  [m]                    –      3947
# 56               405035                0.26%                    –    627566
# 57  Hawkins/WalkerGreen  Hawkins/WalkerGreen  Hawkins/WalkerGreen    Others
#
#                         Margin          Marginswing[l]  Totalvotes
#            %      EV     Votes        %              %  Totalvotes
# 0      0.31%       –  −591,546  −25.46%          2.27%     2323282
# 1      1.92%       –   −36,173  −10.06%          4.67%      359530
# 2      0.01%       –     10457    0.31%          3.81%     3387326
# 3      1.51%       –  −336,715  −27.62%         −0.70%     1219069
# 4      0.66%       –   5103821   29.16%         −0.95%    17500881
# 5      0.82%       –    439745   13.50%          8.59%     3256980
# 6      0.03%       –    366114   20.07%          6.43%     1823857
# 7      0.07%       –     95665   18.97%          7.60%      504346
# 8      1.36%       –    298737   86.75%         −0.02%      344356
# 9      0.15%       –  −371,686   −3.36%         −2.16%    11067456
# 10     0.02%       –     11779    0.24%          5.37%     4999960
# 11     0.37%       –    169266   29.46%         −2.72%      574469
# 12     1.16%       –  −267,098  −30.77%          1.00%      868014
# 13     0.30%       –   1025024   16.99%         −0.08%     6033744
# 14     0.03%       –  −487,103  −16.06%          3.11%     3033121
# 15     0.68%       –  −138,611   −8.20%          1.21%     1690871
# 16  0.07%[o]       –  −201,083  −14.65%          5.95%     1372303
# 17     0.50%       –  −554,172  −25.94%          3.90%     2136768
# 18     0.68%       –  −399,742  −18.61%          1.03%     2148062
# 19     0.15%       –     74335    9.07%          6.11%      819461
# 20     0.16%       –    102331   23.09%          8.28%      443112
# 21     0.15%       –   −27,996   −7.44%          2.85%      376349
# 22     0.87%       –   1008609   33.21%          6.79%     3037030
# 23     0.45%       –   1215000   33.46%          6.26%     3631402
# 24     0.20%       –    154188    2.78%          3.01%     5539302
# 25     0.95%       –    233012    7.11%          5.59%     3277171
# 26     0.61%       –  −217,366  −16.55%          1.28%     1313759
# 27     0.16%       –  −465,722  −15.39%          3.25%     3025962
# 28     0.01%       –   −98,816  −16.37%          4.05%      603674
# 29     0.49%       –  −182,263  −19.06%          5.99%      956383
# 30     0.57%       –   −48,029  −14.92%          5.80%      321886
# 31     0.56%       –     22091    6.50%          8.74%      339666
# 32     0.31%       –  −156,325  −53.02%          1.17%      294831
# 33     1.23%       –     33596    2.39%         −0.03%     1405376
# 34     0.27%       –     59277    7.35%          6.98%      806205
# 35     0.26%       –    725061   15.94%          1.84%     4549353
# 36     0.37%       –     99720   10.79%          2.58%      923965
# 37     0.30%       –   1986187   23.11%          0.62%     8594826
# 38     0.38%       –   −74,483   −1.35%          2.31%     5524804
# 39     0.53%       –  −120,693  −33.36%          2.37%      361819
# 40     0.03%       –  −475,669   −8.03%          0.10%     5922202
# 41     0.76%       –  −516,390  −33.09%          3.99%     1560699
# 42     0.93%       –    381935   16.08%          5.10%     2374321
# 43       [s]       –     80555    1.16%          1.88%     6915283
# 44     1.02%       –    107564   20.77%          5.26%      517757
# 45     0.07%       –  −293,562  −11.68%          2.59%     2513329
# 46         –       –  −110,572  −26.16%          3.63%      422609
# 47     0.76%       –  −708,764  −23.21%          2.80%     3053851
# 48     0.05%       –  −631,221   −5.58%          3.41%    11315056
# 49     1.30%       –  −304,858  −20.48%         −2.40%     1488289
# 50     1.90%       –    130116   35.41%          9.00%      367428
# 51     0.44%       –    451138   10.11%          4.79%     4460524
# 52     0.85%       –    784961   19.20%          3.49%     4087631
# 53     0.01%       –  −309,398  −38.93%          3.14%      794731
# 54     0.53%       –     20682    0.63%          1.40%     3298041
# 55     1.43%       –  −120,068  −43.38%          2.92%      276765
# 56     0.40%       –   7052770    4.45%          2.35%   158383403
# 57    Others  Others    Margin   Margin    Marginswing  Totalvotes

# %%
# textblob
res = TextBlob(text_tokens)
print(res.sentiment.polarity)

# Vader
sid_obj= SentimentIntensityAnalyzer()
print(sid_obj.polarity_scores(text_tokens))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [96], in <cell line: 2>()
#       1 # textblob
# ----> 2 res = TextBlob(text_tokens)
#       3 print(res.sentiment.polarity)
#       5 # Vader
#
# File ~\anaconda3\lib\site-packages\textblob\blob.py:384, in BaseBlob.__init__(self, text, tokenizer, pos_tagger, np_extractor, analyzer, parser, classifier, clean_html)
#     380 def __init__(self, text, tokenizer=None,
#     381             pos_tagger=None, np_extractor=None, analyzer=None,
#     382             parser=None, classifier=None, clean_html=False):
#     383     if not isinstance(text, basestring):
# --> 384         raise TypeError('The `text` argument passed to `__init__(text)` '
#     385                         'must be a string, not {0}'.format(type(text)))
#     386     if clean_html:
#     387         raise NotImplementedError("clean_html has been deprecated. "
#     388                                 "To remove HTML markup, use BeautifulSoup's "
#     389                                 "get_text() function")
#
# TypeError: The `text` argument passed to `__init__(text)` must be a string, not <class 'list'>

# %%
# Function used to geocode locations and override timeout error
def do_geocode(address):
    geopy = Nominatim(user_agent="Twitter_data")
    try:
        return geopy.geocode(address,exactly_one=True, addressdetails=True)
    except GeocoderTimedOut:
        return do_geocode(address)

# Creating Geocoded Location column
tweets_df['GeocodedLocation']=tweets_df['location'].apply(lambda x: do_geocode(x) if x != None else None)

# %%
# Out:
# 0    (Washington, District of Columbia, United Stat...
# 1    (City of New York, New York, United States, (4...
# 2    (Texas, United States, (31.2638905, -98.5456116))
# 3    (Bridgewater, Plymouth County, Massachusetts, ...
# 4    (Annapolis, Anne Arundel County, Maryland, Uni...
# 5                                                 None
# 6    (City of London, Greater London, England, Unit...
# 7    (Tyler, Smith County, Texas, United States, (3...
# Name: GeocodedLocation, dtype: object

# %%
# Use the geopy locator with Nominatim/OpenStreetMaps
locator = Nominatim(user_agent='myGeocoder')
adress = ['New York City']
location = locator.geocode(adress,exactly_one=True, addressdetails=True)
location.raw


county = (location.raw['address']).get('state')
county
# Out:
# 'New York'

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

def city_state_country(adress):
    location = geolocator.geocode(adress, exactly_one=True)
    address = location.raw['address']
    state = address.get('state', '')
    country = address.get('country', '')
    return city, state, country


def do_geocode(address):
    geopy = Nominatim(user_agent="Twitter_data")
    try:
        return geopy.geocode(address,exactly_one=True, addressdetails=True)
    except GeocoderTimedOut:
        return do_geocode(address)

# Creating Geocoded Location column

tweets_df['state']=tweets_df['location'].apply(lambda x: do_geocode(x) if x != None else None)
tweets_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [207], in <cell line: 11>()
#       8     country = address.get('country', '')
#       9     return city, state, country
# ---> 11 print(city_state_country(tweets_df['GeocodedLocation']))
#
# Input In [207], in city_state_country(coord)
#       3 def city_state_country(coord):
#       4     location = geolocator.geocode(coord, exactly_one=True)
# ----> 5     address = location.raw['address']
#       6     city = address.get('city', '')
#       7     state = address.get('state', '')
#
# AttributeError: 'NoneType' object has no attribute 'raw'

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")

state1 = "Denmark"
print("State Name:",state1)
location = geolocator.geocode(state1)
print("State Name/Country Name: ")
print(location.address)
# Out:
# State Name: Denmark
# State Name/Country Name:
# Danmark

# %%
# Function used to geocode locations and override timeout error
def do_geocode(address):
    try:
        geolocator = Nominatim(user_agent="Twitter_location_to_us_state")
        location = geolocator.geocode(adress, addressdetails=True)
        state = location.raw['address']['state']
        return state
        #return geopy.geocode(address,exactly_one=True, addressdetails=True)
    except GeocoderTimedOut:
        return do_geocode(address)

# Creating Geocoded Location column
tweets_df['state']=tweets_df['location'].apply(lambda x: do_geocode(x) if x != None else None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [192], in <cell line: 13>()
#      10         return do_geocode(address)
#      12 # Creating Geocoded Location column
# ---> 13 tweets_df['state']=tweets_df['location'].apply(lambda x: do_geocode(x) if x != None else None)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [192], in <lambda>(x)
#      10         return do_geocode(address)
#      12 # Creating Geocoded Location column
# ---> 13 tweets_df['state']=tweets_df['location'].apply(lambda x: do_geocode(x) if x != None else None)
#
# Input In [192], in do_geocode(address)
#       3 try:
#       4     geolocator = Nominatim(user_agent="Twitter_location_to_us_state")
# ----> 5     location = geolocator.geocode(adress, addressdetails=True)
#       6     state = location.raw['address']['state']
#       7     return state
#
# NameError: name 'adress' is not defined

# %%
tweets_df
# Out:
#                  created_at  \
# 0 2020-12-31 23:39:59+00:00
# 1 2020-12-31 23:38:46+00:00
# 2 2020-12-31 23:26:10+00:00
# 3 2020-12-31 22:27:35+00:00
# 4 2020-12-31 21:52:50+00:00
# 5 2020-12-31 20:53:13+00:00
# 6 2020-12-31 20:46:31+00:00
# 7 2020-12-31 20:42:16+00:00
#
#                                                 text               source  \
# 0  Scientists: We have a #vaccine! \nAMERICANnnnn...  Twitter for Android
# 1                     The #vaccine rollout is a mess   Twitter for iPhone
# 2  All these "pro-life" catholics who refuse to w...  Twitter for Android
# 3  #goodbye2020 #hello2021 #maskup #keephysicaldi...            Instagram
# 4  They won't say WHY?! W.T.H.! Do they know some...  Twitter for Android
# 5  Just in time for the #NewYear!\n\nGrateful for...   Twitter for iPhone
# 6  Look.\n\nEverybody knows that the vaccine is a...  Twitter for Android
# 7           Just got my first #shot of the #vaccine!   Twitter for iPhone
#
#   public_metrics                     name       username  \
# 0           None     Captain Co-dependent     TaeX2times
# 1           None         George Henderson  GeoPHenderson
# 2           None                 McRector      lb_rector
# 3           None       Joe Oravecz, Ph.D.         DrJoeO
# 4           None                RealMaryZ      RealMaryz
# 5           None        aL'Ai alvarez, MD     alvarezzzy
# 6           None  🇺🇦(((The Dividist))) 🇺🇦       Dividist
# 7           None            Paul Buchanan     celadon100
#
#                   location      State_country country_code  verified  \
# 0           Washington, DC      Arlington, VA           US     False
# 1            New York City      Manhattan, NY           US     False
# 2                    Texas         Texas, USA           US     False
# 3          Bridgewater, MA    Bridgewater, MA           US     False
# 4      Annapolis, Maryland    Londontowne, MD           US     False
# 5  #FirstGenMD at Stanford  San Francisco, CA           US     False
# 6                 The City          Tyler, TX           US     False
# 7        Tyler, Texas, USA        Chicago, IL           US     False
#
#                                          description
# 0  🍋🍋🥝🍉🍑  AquaGirl ♒\nHost/ Creator of the Normal...
# 1  Party Planner, Dandy, Man About Town, Former D...
# 2  Music lover. Film fanatic. Craft beer enthusia...
# 3  Vice President: @BridgeStateU "All About the S...
# 4  The Earth is the Mother of all people, and all...
# 5  Well-Being Director|Co-Chair, Human Potential ...
# 6  Social liberal, fiscal conservative, civil lib...
# 7  I am a geochemist who does a bit of research a...

# %%
tweets_df.GeocodedLocation[1]
# Out:
# 0                                                 None
# 1    (Las Vegas, Clark County, Nevada, United State...
# 2    (Plymouth, Hennepin County, Minnesota, United ...
# 3    (Orlando, Orange County, Florida, United State...
# 4    (Brooklyn, Kings County, City of New York, New...
# 5    (City of New York, New York, United States, (4...
# 6    (Fort Lauderdale, Broward County, Florida, Uni...
# 7    (Boston, Suffolk County, Massachusetts, United...
# 8    (Memphis, Shelby County, West Tennessee, Tenne...
# Name: GeocodedLocation, dtype: object

# %%
geolocator = Nominatim(user_agent="dasdasda")
tlocation = geolocator.geocode("Fort Lauderdale")
print(location.address.state)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [182], in <cell line: 3>()
#       1 geolocator = Nominatim(user_agent="dasdasda")
#       2 tlocation = geolocator.geocode("Fort Lauderdale")
# ----> 3 print(location.address.state)
#
# AttributeError: 'str' object has no attribute 'state'

# %%
from geopy.geocoders import Nominatim

# address is a String e.g. 'Berlin, Germany'
# addressdetails=True does the magic and gives you also the details
location = geolocator.geocode("#FirstGenMD at Stanford", addressdetails=True)

location.raw['address']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [198], in <cell line: 7>()
#       3 # address is a String e.g. 'Berlin, Germany'
#       4 # addressdetails=True does the magic and gives you also the details
#       5 location = geolocator.geocode("#FirstGenMD at Stanford", addressdetails=True)
# ----> 7 location.raw['address']
#
# AttributeError: 'NoneType' object has no attribute 'raw'

# %%
class location
# Out:
#   Input In [143]
#     class location
#                   ^
# SyntaxError: invalid syntax

# %%
people = {'adress': {'state': 'Minnesota', 'age': '27', 'sex': 'Male'},
          2: {'name': 'Marie', 'age': '22', 'sex': 'Female'}}

print(people['adress']['state'])
#print(people[1]['age'])
#print(people[1]['sex'])
# Out:
# Minnesota

# %%
print(location['address']['state'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [149], in <cell line: 1>()
# ----> 1 print(location['address']['state'])
#
# File ~\anaconda3\lib\site-packages\geopy\location.py:108, in Location.__getitem__(self, index)
#     104 def __getitem__(self, index):
#     105     """
#     106     Backwards compatibility with geopy<0.98 tuples.
#     107     """
# --> 108     return self._tuple[index]
#
# TypeError: tuple indices must be integers or slices, not str

# %%
tweets_df.location.address
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 tweets_df.location.address
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'address'

# %%
tweets_df.GeocodedLocation[1][0]
# Out:
# 'Las Vegas, Clark County, Nevada, United States'

# %%
# Create the Latitude Column
country=[]
for i in tweets_df['GeocodedLocation']:
    if i== None:
        lat.append(None)
    else:
        lat.append(i.latitude)
tweets_df['Latitude']=lat
tweets_df['Latitude'].astype('float')

# Create the Longitude Column
long=[]
for i in tweets_df['GeocodedLocation']:
    if i== None:
        long.append(None)
    else:
        long.append(i.longitude)
tweets_df['Longitude']=long
tweets_df['Longitude'].astype('float')
# Out:
# 0                                                 None
# 1    (Las Vegas, Clark County, Nevada, United State...
# 2    (Plymouth, Hennepin County, Minnesota, United ...
# 3    (Orlando, Orange County, Florida, United State...
# 4    (Brooklyn, Kings County, City of New York, New...
# 5    (City of New York, New York, United States, (4...
# 6    (Fort Lauderdale, Broward County, Florida, Uni...
# 7    (Boston, Suffolk County, Massachusetts, United...
# 8    (Memphis, Shelby County, West Tennessee, Tenne...
# Name: GeocodedLocation, dtype: object

# %%
# Ref: https://geopy.readthedocs.io/en/stable/#usage-with-pandas
geolocator = Nominatim(user_agent="Twitter_data")

#geocode = RateLimiter(geolocator.geocode, min_delay_seconds=3, max_retries=5)
#tweets_df["location"] = tweets_df["location"].progress_apply(geocode, language="en") # Some locations are in hindi, chinese. Language=’en’ returns location in english
#tweets_df["coordinates"] = tweets_df["location"].apply(lambda loc: tuple(loc.point) if loc else None)
tweets_df["state"] = tweets_df["location"].apply(lambda loc: loc[0].split(',')[0] if loc else None)
#tweets_df["country"] = tweets_df["location"].apply(lambda loc: loc[0].split(',')[-1] if loc else None)
tweets_df
# Out:
#                  created_at  \
# 0 2022-08-10 22:46:23+00:00
# 1 2022-08-10 22:34:33+00:00
# 2 2022-08-10 21:04:18+00:00
# 3 2022-08-10 19:44:28+00:00
# 4 2022-08-10 15:56:16+00:00
# 5 2022-08-10 12:45:49+00:00
# 6 2022-08-10 11:11:56+00:00
# 7 2022-08-10 00:02:57+00:00
# 8 2022-08-09 15:12:09+00:00
#
#                                                 text               source  \
# 0  Can we utilize the absorbable micro needle pat...   Twitter for iPhone
# 1  A combined #influenza and #COVID19 mRNA #vacci...  Twitter for Android
# 2  @michren03 Twitter blocked me after posting th...  Twitter for Android
# 3  To all the “AUTHENTIC/Fake #DL men please go g...   Twitter for iPhone
# 4  Here are some recommended immunizations for ch...   Twitter for iPhone
# 5  All I saw was “sneaky link, who up, come suck ...   Twitter for iPhone
# 6  FDA issues emergency use authorization for new...   Twitter for iPhone
# 7  Got this notice that my appointment to get my ...            Instagram
# 8  📣 Fresh from the press 📑 @scilmmunology\n\nChe...   Twitter for iPhone
#
#   public_metrics                  location country country_code  verified  \
# 0           None  Minneapolis/St. Paul, MN       M           US     False
# 1           None             Las Vegas, NV       L           US     False
# 2           None              Plymouth, MN       P           US     False
# 3           None               Orlando, FL       O           US     False
# 4           None              Brooklyn, NY       B           US     False
# 5           None             New York City       N           US      True
# 6           None           Fort Lauderdale       F           US     False
# 7           None                Boston, MA       B           US     False
# 8           None               Memphis, TN       M           US     False
#
#                                          description  \
# 0  MPH, CIC. Vaccine and Infectious Disease Geek....
# 1  Future of Healthcare & Life Sciences | Science...
# 2  Freelance Photographer/Photojournalist \n📷 @ca...
# 3  35 Black Male Anything else feel free to ask!!...
# 4  COPO is a full-service nonprofit in Brooklyn, ...
# 5                               Reporter @CBSNewYork
# 6                                      Lover of life
# 7  The Official Twitter Account-𝐃𝐚𝐧 𝐁𝐚𝐫𝐨𝐮𝐜𝐡 𝐋𝐚𝐛 a...
# 8  Assistant Professor Department of Community & ...
#
#                                     GeocodedLocation state
# 0                                               None    Mi
# 1  (Las Vegas, Clark County, Nevada, United State...    La
# 2  (Plymouth, Hennepin County, Minnesota, United ...    Pl
# 3  (Orlando, Orange County, Florida, United State...    Or
# 4  (Brooklyn, Kings County, City of New York, New...    Br
# 5  (City of New York, New York, United States, (4...    Ne
# 6  (Fort Lauderdale, Broward County, Florida, Uni...    Fo
# 7  (Boston, Suffolk County, Massachusetts, United...    Bo
# 8  (Memphis, Shelby County, West Tennessee, Tenne...    Me

# %%
# import the pandas library

# create a list of records
tweet_info_ls2 = []
# iterate over each tweet and corresponding user details
for tweet, user in zip(tweets_df, tweets.includes['places']):
    tweet_info2 = {
        'created_at': tweets_df.created_at,
        'text': tweets_df.text,
        'source': tweets_df.source,
        'name': tweets_df.name,
        'username': tweets_df.username,
        'location': tweets_df.location,
        'country': place.full_name,
        'verified': tweets_df.verified,
        'description': tweets_df.description
    }
    tweet_info_ls2.append(tweet_info2)
# create dataframe from the extracted records
tweets_df2 = pd.DataFrame(tweet_info_ls2)
# display the dataframe
tweets_df2
# Out:
#                                           created_at  \
# 0  0   2021-12-08 20:38:34+00:00
# 1   2021-12-08 2...
# 1  0   2021-12-08 20:38:34+00:00
# 1   2021-12-08 2...
# 2  0   2021-12-08 20:38:34+00:00
# 1   2021-12-08 2...
# 3  0   2021-12-08 20:38:34+00:00
# 1   2021-12-08 2...
# 4  0   2021-12-08 20:38:34+00:00
# 1   2021-12-08 2...
# 5  0   2021-12-08 20:38:34+00:00
# 1   2021-12-08 2...
#
#                                                 text  \
# 0  0    En dag som i dag vil jeg ønske at jeg boe...
# 1  0    En dag som i dag vil jeg ønske at jeg boe...
# 2  0    En dag som i dag vil jeg ønske at jeg boe...
# 3  0    En dag som i dag vil jeg ønske at jeg boe...
# 4  0    En dag som i dag vil jeg ønske at jeg boe...
# 5  0    En dag som i dag vil jeg ønske at jeg boe...
#
#                                               source  \
# 0  0    Twitter for Android
# 1    Twitter for Andr...
# 1  0    Twitter for Android
# 1    Twitter for Andr...
# 2  0    Twitter for Android
# 1    Twitter for Andr...
# 3  0    Twitter for Android
# 1    Twitter for Andr...
# 4  0    Twitter for Android
# 1    Twitter for Andr...
# 5  0    Twitter for Android
# 1    Twitter for Andr...
#
#                                                 name  \
# 0  0                      Bjarni Klein Olsen 🇫🇴
# 1...
# 1  0                      Bjarni Klein Olsen 🇫🇴
# 1...
# 2  0                      Bjarni Klein Olsen 🇫🇴
# 1...
# 3  0                      Bjarni Klein Olsen 🇫🇴
# 1...
# 4  0                      Bjarni Klein Olsen 🇫🇴
# 1...
# 5  0                      Bjarni Klein Olsen 🇫🇴
# 1...
#
#                                             username  \
# 0  0         KleinOlsen
# 1           evafogdk
# 2   ...
# 1  0         KleinOlsen
# 1           evafogdk
# 2   ...
# 2  0         KleinOlsen
# 1           evafogdk
# 2   ...
# 3  0         KleinOlsen
# 1           evafogdk
# 2   ...
# 4  0         KleinOlsen
# 1           evafogdk
# 2   ...
# 5  0         KleinOlsen
# 1           evafogdk
# 2   ...
#
#                                             location  \
# 0  0          Føroyar, Streimoy
# 1               ...
# 1  0          Føroyar, Streimoy
# 1               ...
# 2  0          Føroyar, Streimoy
# 1               ...
# 3  0          Føroyar, Streimoy
# 1               ...
# 4  0          Føroyar, Streimoy
# 1               ...
# 5  0          Føroyar, Streimoy
# 1               ...
#
#                                              country  \
# 0  0    Vordingborg, Danmark
# 1    Vordingborg, Da...
# 1  0    Vordingborg, Danmark
# 1    Vordingborg, Da...
# 2  0    Vordingborg, Danmark
# 1    Vordingborg, Da...
# 3  0    Vordingborg, Danmark
# 1    Vordingborg, Da...
# 4  0    Vordingborg, Danmark
# 1    Vordingborg, Da...
# 5  0    Vordingborg, Danmark
# 1    Vordingborg, Da...
#
#                                             verified  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# 4 ...
# 1  0    False
# 1    False
# 2    False
# 3    False
# 4 ...
# 2  0    False
# 1    False
# 2    False
# 3    False
# 4 ...
# 3  0    False
# 1    False
# 2    False
# 3    False
# 4 ...
# 4  0    False
# 1    False
# 2    False
# 3    False
# 4 ...
# 5  0    False
# 1    False
# 2    False
# 3    False
# 4 ...
#
#                                          description
# 0  0    Hjemvendt færing, tilbage på øerne efter ...
# 1  0    Hjemvendt færing, tilbage på øerne efter ...
# 2  0    Hjemvendt færing, tilbage på øerne efter ...
# 3  0    Hjemvendt færing, tilbage på øerne efter ...
# 4  0    Hjemvendt færing, tilbage på øerne efter ...
# 5  0    Hjemvendt færing, tilbage på øerne efter ...

# %%
import tweepy

client = tweepy.Client(bearer_token=MY_BEARER_TOKEN)

# Replace with your own search query
query = 'covid -is:retweet place_country:DK'

tweets = client.search_all_tweets(query=query, 
                                  tweet_fields=['context_annotations', 'created_at', 'geo'],
                                  place_fields=['place_type', 'country'], 
                                  expansions='geo.place_id', max_results=10)

# Get list of places from includes object
places = {p["id"]: p for p in tweets.includes['places']}

for tweet in tweets.data:
    print(tweet.id)
    print(tweet.text)
    if places[tweet.geo['place_id']]:
        place = places[tweet.geo['place_id']]
        print(place.full_name)
# Out:
# 1557836753897230336
# @JohnH1337 @stinuslindgreen Nej pesticider, PFAS, PFOS osv kan ikke give Covid, men det kan gøre dig mindre modstandsdygtig over for sygdom inkl. C. Tænker ikke at man bliver syg af et glas, men over tid bliver det til meget + blandet med hvor vi ellers udsætters for det og så er vi oppe på store mængder ?
# København, Danmark
# 1557662964148326402
# @stinuslindgreen Det meste af mit voksne liv har jeg råbt op om klimaforandring, været glad for min stofpose osv.. Der udledes ekstrem meget kemi ud i vores grundvand og direkte ud i vores haner, kemi der under Covid har lært os, om du spiser/drikker det, ifører dig det eller indånder det, så r👇🏻
# København, Danmark
# 1557090026336538626
# @mikemwilson @Lil_Pedro4Lyfe Wait… a new covid variant that is…. Er… undetectable? I’ve had fluish symps for two months on/off, mostly on.
# København, Danmark
# 1557022011007852544
# @anders_hviid @NatureComms Is COVID-19 one disease or different diseases related to different strains of the virus?
# Vordingborg, Danmark
# 1556953476831318017
# @CBroendsholmA Så længe man kan smittes, kan man også få senfølger og heldigvis er Covid ikke livstruende for sunde og raske børn. Mon ikke det bliver som med andre vacciner, at den kan tilvælges gratis eller betalt med tiden. Men du synes at det haster eller hvori ligger din bekymring ? 🙂
# København, Danmark
# 1556737962767007744
# @Nikolajlaesoee @Jenbas1 https://t.co/fR1o0h1lgN
# Frederiksberg, Danmark
# 1556625378021675008
# @PaulaLarrain1 Det virker ærligt talt som en måde at tjene politiske points på et område hvor der selvsagte er forargelse over udviklingen i US, men ikke noget reelt problem der skal løses her. Det har vi til gengæld med psykiatrien og den skræmmende selvmordstendens blandt unge efter Covid.
# Helsingør, Danmark
# 1556346752428609542
# These are the world's most powerful passports, according to the Henley Passport Index 2022 https://t.co/a4bTHuZz4D via @luxury
# Frederiksberg, Danmark
# 1556229184590151682
# Two flight cancellations home from Copenhagen means I’ll be missing my first @SalfordDevils match (except for the Covid games) in over 9 years. Hoping for another rare win at Headingley!
#
# Making up for it with tickets for the Copenhagen derby today! @FCKobenhavn @BrondbyIF
# København, Danmark
# 1555802474975485952
# Nein, Korrelation impliziert noch keine Kausalität. Vielleicht gehen Eltern von geimpften Kindern schneller zum Arzt? Vielleicht haben Kinder mit erhöhtem Risiko auf Long-Covid eine höhere Impfquote? Oder das Risiko ist nach Impfung höher? Kann man anhand diesen Daten nicht sagen https://t.co/cGxbpuB7C2
# Vordingborg, Danmark
