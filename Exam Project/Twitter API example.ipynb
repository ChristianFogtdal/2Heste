# %%
import webbrowser

# %%
# Python Script to Extract tweets of a
# particular Hashtag using Tweepy and Pandas
 
# import modules
import pandas as pd
import tweepy
 
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
 
 
# function to perform data extraction
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               words, lang="da",
                               since_id=date_since,
                               tweet_mode='extended').items(10)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)
 
if __name__ == '__main__':
 
        # Enter your own credentials obtained
        # from your developer account
        consumer_key = 'X6oaPMBWYauiGFe9Z9KeCW5HN'
        consumer_secret = 'UCvW1Bb3CkXruyVbdhO1CDE1x2kvsrsWEBhA6mk8Mrn7fTF9Ku'
        callback_url = 'oob'
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_url)

        try:
            redirect_url = auth.get_authorization_url()
        except tweepy.errors.TweepyException:
            print('Error! Failed to get request token.')

        webbrowser.open(redirect_url)

        user_pin_input = input('What is the pin value? ')
        auth.get_access_token(user_pin_input)
        api = tweepy.API(auth)

 
        # Enter Hashtag and initial date
        print("Enter Twitter HashTag to search for")
        words = input()
        print("Enter Date since The Tweets are required in yyyy-mm--dd")
        date_since = input()
 
        # number of tweets you want to extract in one run
        numtweet = 10
        scrape(words, date_since, numtweet)
        print('Scraping has completed!')
# Out:
# What is the pin value?  0929786
# Enter Twitter HashTag to search for
#  vaccine
# Enter Date since The Tweets are required in yyyy-mm--dd
#  2022-08--10
# Tweet 1:
# Username:MadsOlesenDK
# Description:
# Location:
# Following Count:15
# Follower Count:0
# Total Tweets:90
# Retweet Count:0
# Tweet Text:@cb_hagen @JonPloug så hvad kan vi gøre ? Vi kan satse på at en kombination af immunitet, dvs. fra smitte og vaccine, kan give mildere forløb overall, og bedre immunitet fremadrettet (så vi måske ikke står det samme sted igen i 2022). Vi har måske også en bedre vaccine til den tid (BV Nordic).
# Hashtags Used:[]
#
# Tweet 2:
# Username:MadsOlesenDK
# Description:
# Location:
# Following Count:15
# Follower Count:0
# Total Tweets:90
# Retweet Count:0
# Tweet Text:@cb_hagen @JonPloug ...Det sidste er sandsynligvis fordi vi ikke har postet milliarder i bavarian nordics vaccine up front - havde vi gjort det, så havde vi nok haft den ca. 4 måneder efter pfizers.
# Hashtags Used:[]
#
# Tweet 3:
# Username:CTVMontreal
# Description:Montreal’s most popular English-language newscast. Tweeting breaking local news from https://t.co/HEKEN15ku7.
# Location:Montreal
# Following Count:914
# Follower Count:189929
# Total Tweets:184878
# Retweet Count:0
# Tweet Text:PnuVax, Biolyse Pharma join forces to produce monkeypox vaccine  https://t.co/ZbDRjemZ9F
# Hashtags Used:[]
#
# Tweet 4:
# Username:ngklausen
# Description:Social liberal demokrat, med svær allergi over for magtmisbrug.
#
# Vi skal beskytte vores demokrati og frihed, det må ikke ofres for lidt midlertidige sikkerhed.
# Location:
# Following Count:75
# Follower Count:70
# Total Tweets:3318
# Retweet Count:0
# Tweet Text:@Heunicke @SSTSundhed En af de store udfordringer med den valgte vaccine strategi og kommunikation om hvem der er i risiko gruppen er, at alle mænd der bliver smittede automatisk antages af alle andre, at have sex med andre mænd, hvilket for mange nok reducere ønsket om nogen skal kende til ens smitte
# Hashtags Used:[]
#
# Tweet 5:
# Username:mrsNoGenJuice
# Description:shiatsu acupressur therapist from the shiatsu academi
# Location:
# Following Count:852
# Follower Count:809
# Total Tweets:4377
# Retweet Count:0
# Tweet Text:MONKEYpox vaccine stadig i forsøg…https://t.co/AWDFj5osnH https://t.co/IDi8OdzwQF
# Hashtags Used:[]
#
# Tweet 6:
# Username:senna413
# Description:
# Location:DK
# Following Count:316
# Follower Count:98
# Total Tweets:1707
# Retweet Count:0
# Tweet Text:@Louisevnielse Mega glad for at vi ikke tog imod tilbuddet om vaccine til vores børn, men samtidig kan jeg ikke lade være med at tænke på venner og bekendte der sprang på den. Især dem der tog den for at beskytte deres nærmeste.
# Jeg ville være rødglødende af raseri hvis det var mine unger. 🤯
# Hashtags Used:[]
#
# Tweet 7:
# Username:Park_Triolo
# Description:
# Location:
# Following Count:92
# Follower Count:25
# Total Tweets:292
# Retweet Count:0
# Tweet Text:@alexanderlindh2 @StabellBenn I kan starte med min kone, datter og jeg. Pfizers vaccine (og Mette-monsteret) slog min far ihjel (uforklarlig AIH) og vores familielæge frarådede os efterfølgende at tage vaccinen, så det har vi naturligvis ikke gjort og kommer heller ikke til det.
# Hashtags Used:[]
#
# Tweet 8:
# Username:TineLPetersen
# Description:If you are not mad you are not paying attention.
#
# GETTR: Dame TinePetersen of Portimão
# Location:Portugal
# Following Count:267
# Follower Count:208
# Total Tweets:3977
# Retweet Count:1
# Tweet Text:Børn / unge under 18 år tilbydes fra 1/9-2022 ikke længere Covid vaccination 🎉🦄 da virus ikke er farlig for dem🦄
#
# Er I ikke glade for at I ikke løb risikoen og lod jeres børn / unge vaccinere med en vaccine I ikke kender langtidsbivirkningerne af💔🫀☠️🫀💔💔☠️🦄🙈
# Hashtags Used:[]
#
# Tweet 9:
# Username:LonePehrson3
# Description:
# Location:Middelfart, Danmark
# Following Count:276
# Follower Count:157
# Total Tweets:3233
# Retweet Count:0
# Tweet Text:@MadsenLunding @PrmMortensen @LarsAJ Ja de er døde af det giftige vaccine.
# Hashtags Used:[]
#
# Tweet 10:
# Username:VivianAnitaAlex
# Description:President of the political party Community Spirit. I was charged with terrorism for posting a picture of a burning doll that resembled Denmark's prime minister.
# Location:
# Following Count:106
# Follower Count:134
# Total Tweets:184
# Retweet Count:0
# Tweet Text:Regeringen giver dig belønninger hvis du gør som de siger og forblænder dig med goder hvis du følger deres ordre. Kan I se i blev tvunget til at tage en vaccine, blev testet og maskeret, for at være frie? Ønsker i nogen skal tage ansvar for det, så stem på #partietsamfundssind 🧡 https://t.co/JTFU2Qko4U
# Hashtags Used:['partietsamfundssind']
# Scraping has completed!
